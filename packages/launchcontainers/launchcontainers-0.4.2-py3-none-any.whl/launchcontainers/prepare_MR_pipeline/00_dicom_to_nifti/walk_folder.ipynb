# %%
import os
join=os.path.join

# %%
folder=[]
layer=1
dir='/bcbl/home/public/Gari/VOTCLOC/fLoc_pilot/dicom'
sub='sub-02'
w=os.walk(join(dir,sub))
for (dirpath,dirname,filename) in w:
    print(dirname)

folder
# Out:
# ['ses-day6BCBL', 'ses-day5BCBL']
# ['04030000', '04030003', '04030006', '04030001', '04030004', '04030007', '04030002', '04030005']
# []
# []
# []
# []
# []
# []
# []
# []
# ['08310002', '08310006', '08310000', '08310004', '08310005', '08310003', '08310007', '08310001']
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
folder
# Out:
# ['/bcbl/home/public/Gari/VOTCLOC/fLoc_pilot/dicom/sub-02',
#  ['ses-day6BCBL', 'ses-day5BCBL'],
#  [],
#  '/bcbl/home/public/Gari/VOTCLOC/fLoc_pilot/dicom/sub-02/ses-day6BCBL',
#  ['04030000',
#   '04030003',
#   '04030006',
#   '04030001',
#   '04030004',
#   '04030007',
#   '04030002',
#   '04030005'],
#  [],
#  '/bcbl/home/public/Gari/VOTCLOC/fLoc_pilot/dicom/sub-02/ses-day6BCBL/04030000',
#  [],
#  ['26031323',
#   '26034238',
#   '26033171',
#   '26036086',
#   '26032698',
#   '26033512',
#   '26035360',
#   '26031972',
#   '26034887',
#   '26031004',
#   '26032379',
#   '26035701',
#   '26035041',
#   '26035734',
#   '26033226',
#   '26035074',
#   '26031686',
#   '26032500',
#   '26035415',
#   '26030960',
#   '26033875',
#   '26032533',
#   '26035448',
#   '26031367',
#   '26034381',
#   '26030993',
#   '26034722',
#   '26032214',
#   '26035129',
#   '26034062',
#   '26033589',
#   '26034403',
#   '26036251',
#   '26031521',
#   '26034436',
#   '26032896',
#   '26033710',
# ...
